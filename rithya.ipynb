# %% [markdown]
# # <span style='color:red'> <u>Predictive Modeling for Data science job salary prediction  Using Machine Learning.
#   n

# %% [markdown]
# ## <span style='color:indigo'> Name : Suchithra.P

# %% [markdown]
# ## <span style='color:indigo'> Organization : EntryElevate
# ## <span style='color:indigo'> Submission date : 01/07/2024

# %% [markdown]
# ## <span style='color:teal'>Table of Contents
#     1.Overview of Problem Statement
#     2. Objective
#     3. Data Collection
#     4. Data Description
#     5. Exploratory Data Analysis (EDA)
#     6. Data Preprocessing
#     7. Visualization
#     8. Feature Engineering]
#     9. Data Splitting
#     10.Model Selection
#     11.Model Training & Evaluation
#     12.Feature Selection
#     13.Model Evaluation
#     14.Hyperparameter Tuning
#     15.Result
#     16.Model Deployment
#     17.Limitations
#     18.Conclusion
#     19.Future Work

# %% [markdown]
# # <span style='color:blue'>1. Overview of Problem Statement

# %% [markdown]
# ### To develop a predictive model that accurately estimates the salary of data scientists based on various features. The goal is to understand how different factors influence salaries and to provide insights for both job seekers and employers.

# %% [markdown]
# # <span style='color:blue'>2. Objective

# %% [markdown]
# ### The objective of this project is to develop a machine learning model that accurately predicts data scientist salaries based on various job-related and demographic features. The model aims to estimate salaries reliably for data scientists, determine the impact of different features on salary outcomes, and help data scientists make informed career decisions. Additionally, the model will assist employers in setting competitive and fair salaries, provide insights into salary trends across different regions, experience levels, and company sizes, and promote fair compensation practices through data-driven insights. By achieving these goals, the project will support both individual career advancement and organizational effectiveness in the data science field.

# %%
# Ignore warninggs
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # <span style='color:blue'>3. Data collection

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\spsuc\\OneDrive\\Desktop\\Latest_Data_Science_Salaries.csv")
df
# Out:
#                      Job Title Employment Type Experience Level  \
# 0                Data Engineer       Full-Time           Senior
# 1                Data Engineer       Full-Time           Senior
# 2                Data Engineer       Full-Time           Senior
# 3                Data Engineer       Full-Time           Senior
# 4               Data Scientist       Full-Time           Senior
# ...                        ...             ...              ...
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 0             Expert   210000  United States Dollar    United States
# ...

# %%
df.head()
# Out:
#         Job Title Employment Type Experience Level Expertise Level  Salary  \
# 0   Data Engineer       Full-Time           Senior          Expert  210000
# 1   Data Engineer       Full-Time           Senior          Expert  165000
# 2   Data Engineer       Full-Time           Senior          Expert  185900
# 3   Data Engineer       Full-Time           Senior          Expert  129300
# 4  Data Scientist       Full-Time           Senior          Expert  140000
#
#         Salary Currency Company Location  Salary in USD Employee Residence  \
# 0  United States Dollar    United States         210000      United States
# 1  United States Dollar    United States         165000      United States
# 2  United States Dollar    United States         185900      United States
# 3  United States Dollar    United States         129300      United States
# 4  United States Dollar    United States         140000      United States
#
#   Company Size  Year
# 0       Medium  2023
# ...

# %%
df.tail()
# Out:
#                      Job Title Employment Type Experience Level  \
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 3295          Expert   412000  United States Dollar    United States
# 3296    Intermediate   151000  United States Dollar    United States
# 3297          Junior   105000  United States Dollar    United States
# 3298          Junior   100000  United States Dollar    United States
# 3299          Expert  7000000          Indian Rupee            India
#
#       Salary in USD Employee Residence Company Size  Year
# 3295         412000      United States        Large  2020
# ...

# %% [markdown]
# # <span style='color:blue'>4. Data Description

# %% [markdown]
# ### Data Source : kaggle.com

# %% [markdown]
# ## [Dataset](https://www.kaggle.com/datasets/iamsouravbanerjee/data-science-salaries-2023/data)

# %% [markdown]
# + job title: The title or designation of the job position held by the individual.
# + employment type:The nature of employment, such as full-time, part-time, contract, freelance, etc.
# + experience level: The level of experience of the employee, typically categorized into junior, mid-level, senior, etc.
# + expertise level: The level of expertise or skill proficiency related to the job role.,
# + salary currency: The currency in which the salary is denominated, which in this case is USD.
# + company location: The geographical location of the company where the employee works.
# + employee residency: The residency status or location of the employee.
# + company size: The size of the company based on the number of employees, categorized as small, medium, large.
# + Salary :feature represents the monetary compensation earned by data scientists and is the target variable predicted by the machine learning model based on job-related and demographic characteristics.
# + year: The year in which the salary information was recorded or relevent.
# + salary in USD : The salary amount in US dollars (USD) for the respective job position.

# %% [markdown]
# ### Dataset Size
# +
# Number of records: The total number of records in the dataset i 3300,
# Number of features:  13

# %% [markdown]
# ## Importing Necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#                      Job Title Employment Type Experience Level  \
# 0                Data Engineer       Full-Time           Senior
# 1                Data Engineer       Full-Time           Senior
# 2                Data Engineer       Full-Time           Senior
# 3                Data Engineer       Full-Time           Senior
# 4               Data Scientist       Full-Time           Senior
# ...                        ...             ...              ...
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 0             Expert   210000  United States Dollar    United States
# ...

# %% [markdown]
# # <span style='color:blue'> 5. Exploratory Data Analysis(EDA)

# %%
# To get the dimension of the dataset
df.shape
# Out:
# (3300, 11)

# %%
# To get the concise summary of a Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3300 entries, 0 to 3299
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           3300 non-null   object
#  1   Employment Type     3300 non-null   object
#  2   Experience Level    3300 non-null   object
#  3   Expertise Level     3300 non-null   object
#  4   Salary              3300 non-null   int64
#  5   Salary Currency     3300 non-null   object
#  6   Company Location    3300 non-null   object
#  7   Salary in USD       3300 non-null   int64
#  8   Employee Residence  3300 non-null   object
#  9   Company Size        3300 non-null   object
#  10  Year                3300 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 283.7+ KB

# %%
# columns
df.columns
# Out:
# Index(['Job Title', 'Employment Type', 'Experience Level', 'Expertise Level',
#        'Salary', 'Salary Currency', 'Company Location', 'Salary in USD',
#        'Employee Residence', 'Company Size', 'Year'],
#       dtype='object')

# %%
# Data types of each columns in the dataframe
df.dtypes
# Out:
# Job Title             object
# Employment Type       object
# Experience Level      object
# Expertise Level       object
# Salary                 int64
# Salary Currency       object
# Company Location      object
# Salary in USD          int64
# Employee Residence    object
# Company Size          object
# Year                   int64
# dtype: object

# %% [markdown]
# ## Identifying numerical and categorical columns

# %%
# Numerical columns
num_cols = df.select_dtypes(include='int').columns
print(num_cols)
# Out:
# Index(['Salary', 'Salary in USD', 'Year'], dtype='object')

# %%
# Categorical columns
cat_cols = df.select_dtypes(include=['object','datetime']).columns
print(cat_cols)
# Out:
# Index(['Job Title', 'Employment Type', 'Experience Level', 'Expertise Level',
#        'Salary Currency', 'Company Location', 'Employee Residence',
#        'Company Size'],
#       dtype='object')

# %% [markdown]
# ### Out of 11 columns, 3 are numerical and 8 are categorical

# %% [markdown]
# ## Checking for null values

# %%
# finding missing values
df.isnull().sum()
# Out:
# Job Title             0
# Employment Type       0
# Experience Level      0
# Expertise Level       0
# Salary                0
# Salary Currency       0
# Company Location      0
# Salary in USD         0
# Employee Residence    0
# Company Size          0
# Year                  0
# dtype: int64

# %% [markdown]
# ### There are no missing value

# %% [markdown]
# ## Checking for duplicates

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### There are no duplicate values

# %% [markdown]
# ## Understand the distribution of data

# %%
# Statistical summary
df.describe().T
# Out:
#                 count           mean            std      min      25%  \
# Salary         3300.0  204662.292121  727938.294522  14000.0  94169.0
# Salary in USD  3300.0  142095.983939   69028.235512  15000.0  90000.0
# Year           3300.0    2022.495455       0.716355   2020.0   2022.0
#
#                     50%       75%         max
# Salary         140000.0  190000.0  30400000.0
# Salary in USD  136000.0  185000.0    450000.0
# Year             2023.0    2023.0      2023.0

# %%
# statistical summary of columns with data type 'object'
df.describe(include='object').T
# Out:
#                    count unique                   top  freq
# Job Title           3300    111         Data Engineer   702
# Employment Type     3300      4             Full-Time  3261
# Experience Level    3300      4                Senior  2065
# Expertise Level     3300      4                Expert  2065
# Salary Currency     3300     22  United States Dollar  2770
# Company Location    3300     71         United States  2495
# Employee Residence  3300     83         United States  2453
# Company Size        3300      3                Medium  2707

# %%
#Histograms for numerical columns
df[num_cols].hist(bins=15,layout=(2,3))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights:
# + 1.The histogram for "Salary" appears highly skewed with most values concentrated at the lower end. The x-axis scale indicates a wide range, with the majority of data points clustered around zero and a few extending to higher values.
#
# + 2.The histogram for "Salary in USD" shows a more normal distribution compared to "Salary." The values range from 0 to approximately 400,000. There is a peak around 200,000, suggesting that most salaries are concentrated around this value.
#
# + 3.The histogram for "Year" indicates data collected over a few specific years, with the most data points concentrated around 2022. There are very few data points for years prior to 2020, suggesting a recent collection period or a dataset focused primarily on recent years.
# Overall, the "Salary" data shows high skewness, while "Salary in USD" has a more typical distribution. The "Year" data indicates a recent focus, with most entries from 2022.
#
# + Overall, the "Salary" data shows high skewness, while "Salary in USD" has a more typical distribution. The "Year" data indicates a recent focus, with most entries from 2022.

# %%
#box plotto identify outliers
plt.figure()
#enumerate() is a built in python function that allows you to loop over an iterable (like a list) and have an automatic counter.
for i, col in enumerate(num_cols):
    plt.subplot(2,3,i+1)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# + ### The box plots indicate that "Salary" has many extreme outliers with most data concentrated near the lower end. "Salary in USD" also shows some outliers but has a more balanced distribution. The "Year" data is mostly around 2022, with one outlier from an earlier year.

# %%
# Loop through each numerical column to create scatter plots
for i, col in enumerate(num_cols):
    plt.subplot(3,2,i+1)
    sns.scatterplot(data=df,x=col,y='Salary')
    plt.xlabel(col)
    plt.title(f'{col} vs Salary',color= 'red')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Skewness and Kurtosis

# %%
from scipy.stats import skew, kurtosis

#claculate skewness and kurtosis
skewness = df[num_cols].apply(skew)
kurt = df[num_cols].apply(lambda x: kurtosis(x,fisher=False))

print(skewness)
print(kurt)

#Identify positive and negative skewness (absolute value>1)
positive_skewness = skewness[skewness > 1]
negative_skewness = skewness[skewness < -1]

print('variable with positive skewness (skew > 1):\n', positive_skewness)
print('variable with negative skewness (skew < -1):\n', negative_skewness)

# Identify the platykurtic (kurtosis < 3) and leptokurtic (kurtosis > 3) distributions
platykurtic = kurt[kurt < 3]
leptokurtic = kurt[kurt > 3]

print('variables with platykurtic distribution (kurtosis < 3):\n', platykurtic)
print('variables with leptokurtic distribution (kurtosis > 3):\n', leptokurtic)
# Out:
# Salary           25.998369
# Salary in USD     0.647534
# Year             -1.419038
# dtype: float64
# Salary           947.044895
# Salary in USD      3.564442
# Year               4.717099
# dtype: float64
# variable with positive skewness (skew > 1):
#  Salary    25.998369
# dtype: float64
# variable with negative skewness (skew < -1):
#  Year   -1.419038
# dtype: float64
# variables with platykurtic distribution (kurtosis < 3):
#  Series([], dtype: float64)
# variables with leptokurtic distribution (kurtosis > 3):
#  Salary           947.044895
# Salary in USD      3.564442
# Year               4.717099
# dtype: float64

# %% [markdown]
# + ### Skewness:
# + The numerical features are relatively symmetrical, with no significant skewness (absolute value > 1).
# + Positive: 'Salary' is right-skewed (more lower salaries, few higher ones).
# + Negative: 'Year' is left-skewed (more recent years overrepresented).
#
# + ### Kurtosis:
# + All numerical features have kurtosis values less than 3, indicating platykurtic distributions, meaning they have lighter tails and flatter peaks compared to a normal distribution.

# %% [markdown]
# ## Correlation

# %%
# correlation with heatmap to interpret the relation and multicollinarity
plt.figure()
sns.heatmap(df[num_cols].corr(),annot=True,cmap = 'viridis')
# Out:
# <Axes: >

# %% [markdown]
# + #### 1.Salary and SalaryinUSD:The correlation coefficient is -0.026, which indicates a very weak negative correlation. This suggests that there is almost no linear relationship between Salary and SalaryinUSD.
# + #### 2.Salary and Year:The correlation coefficient is -0.099, which indicates a weak negative correlation. This suggests that as Year increases, Salary tends to slightly decrease, though the relationship is not strong.
# + #### 3.SalaryinUSD and Year:The correlation coefficient is 0.23, which indicates a weak positive correlation. This suggests that as Year increases, SalaryinUSD tends to increase slightly.

# %% [markdown]
# ## Multicollinearity
# + here no multicollinearity

# %% [markdown]
# ## Analysing Categorical columns

# %%
for col in cat_cols:
    print(f'Values in {col}:\n{df[col].unique()}')
    print(f'Number of unique values in {col}: {df[col].nunique()}\n')
# Out:
# Values in Job Title:
# ['Data Engineer' 'Data Scientist' 'Analytics Engineer'
#  'Business Intelligence Developer' 'Machine Learning Engineer'
#  'Data Analyst' 'Decision Scientist' 'Machine Learning Software Engineer'
#  'BI Developer' 'Machine Learning Scientist' 'BI Analyst' 'Data Manager'
#  'Business Intelligence Engineer' 'ML Engineer' 'Data Science Manager'
#  'AI Programmer' 'Applied Scientist' 'Data Analytics Manager'
#  'Research Engineer' 'Research Scientist' 'Data Lead' 'Data Strategist'
#  'Data Quality Analyst' 'Data Architect' 'AI Architect'
#  'Computer Vision Engineer' 'Business Intelligence Analyst'
#  'Principal Data Scientist' 'Staff Machine Learning Engineer'
#  'Staff Data Scientist' 'Consultant Data Engineer'
#  'Machine Learning Specialist' 'Head of Data' 'Data Quality Engineer'
#  'Research Analyst' 'Principal Machine Learning Engineer'
#  'Deep Learning Engineer' 'Data Visualization Specialist' 'MLOps Engineer'
# ...

# %% [markdown]
# + JobTitle: There are 104 unique job titles.
# + EmploymentType: There are 4 unique values.
# + ExperienceLevel: There are 4 unique values.
# + ExpertiseLevel: There are 4 unique values.
# + SalaryCurrency: There are 11 unique currencies.
# + CompanyLocation: There are 64 unique company locations.
# + EmployeeResidence: There are 77 unique residence locations for employees.

# %%
for col in cat_cols:
    cross_tab = pd.crosstab(df['Salary'], df[col])
    print(f'Cross Tabulation between {col} and Salary:')
    print(cross_tab)
    print('\n')
# Out:
# Cross Tabulation between Job Title and Salary:
# Job Title  AI Architect  AI Developer  AI Programmer  AI Scientist  \
# Salary
# 14000                 0             0              0             0
# 15000                 0             0              0             0
# 16000                 0             0              0             0
# 18000                 0             0              0             0
# 19000                 0             0              0             0
# ...                 ...           ...            ...           ...
# 7000000               0             0              0             0
# 7500000               0             0              0             0
# 8500000               0             0              0             0
# 11000000              0             0              0             0
# 30400000              0             0              0             0
#
# Job Title  AWS Data Architect  Analytics Engineer  \
# Salary
# ...

# %%
pd.crosstab(df['Salary'], df['Job Title'], margins = True)
# Out:
# Job Title  AI Architect  AI Developer  AI Programmer  AI Scientist  \
# Salary
# 14000                 0             0              0             0
# 15000                 0             0              0             0
# 16000                 0             0              0             0
# 18000                 0             0              0             0
# 19000                 0             0              0             0
# ...                 ...           ...            ...           ...
# 7500000               0             0              0             0
# 8500000               0             0              0             0
# 11000000              0             0              0             0
# 30400000              0             0              0             0
# All                   4             9              4            18
#
# Job Title  AWS Data Architect  Analytics Engineer  \
# Salary
# 14000                       0                   0
# ...

# %%
pd.crosstab(df['Salary'], df['Employment Type'], margins = True)
# Out:
# Employment Type  Contract  Freelance  Full-Time  Part-Time   All
# Salary
# 14000                   0          0          0          1     1
# 15000                   0          0          3          0     3
# 16000                   0          0          1          0     1
# 18000                   0          0          1          0     1
# 19000                   0          0          0          1     1
# ...                   ...        ...        ...        ...   ...
# 7500000                 0          0          1          0     1
# 8500000                 0          0          1          0     1
# 11000000                0          0          2          0     2
# 30400000                0          0          1          0     1
# All                    15         11       3261         13  3300
#
# [1072 rows x 5 columns]

# %%
pd.crosstab(df['Salary'], df['Company Size'], margins = True)
# Out:
# Company Size  Large  Medium  Small   All
# Salary
# 14000             0       0      1     1
# 15000             2       1      0     3
# 16000             1       0      0     1
# 18000             0       0      1     1
# 19000             0       0      1     1
# ...             ...     ...    ...   ...
# 7500000           1       0      0     1
# 8500000           0       0      1     1
# 11000000          2       0      0     2
# 30400000          1       0      0     1
# All             442    2707    151  3300
#
# [1072 rows x 4 columns]

# %% [markdown]
# # <span style='color:blue'>6. Data Preprocessing

# %%
df1 = df.copy()
df1.shape
# Out:
# (3300, 11)

# %%
df1.columns
# Out:
# Index(['Job Title', 'Employment Type', 'Experience Level', 'Expertise Level',
#        'Salary', 'Salary Currency', 'Company Location', 'Salary in USD',
#        'Employee Residence', 'Company Size', 'Year'],
#       dtype='object')

# %% [markdown]
# + ### Unnecessary Columns to Consider Dropping:
#
# + 'Salary Currency': If all salary values are already converted to 'Salary in USD', keeping 'Salary Currency' could be redundant.
# + 'Salary in USD': If 'Salary' already represents salaries in USD, 'Salary in USD' might be redundant.
# + 'Employee Residence': Unless it directly influences salary predictions or your analysis goals, 'Employee Residence' could potentially be unnecessary.

# %%
df1.drop(['Salary Currency','Salary in USD','Employee Residence'],axis = 1,inplace = True)
df1.shape
# Out:
# (3300, 8)

# %%
df1.isnull().sum()
# Out:
# Job Title           0
# Employment Type     0
# Experience Level    0
# Expertise Level     0
# Salary              0
# Company Location    0
# Company Size        0
# Year                0
# dtype: int64

# %% [markdown]
# + For the missing value treatment we can use mean, median, mode or KNNimputer. KNNImputer is a method usedfor imputing missing values by using the k-nearest neighbors approach.But here we have no missing values in this dataset.'Salary' is the target variable. Since there are no null values, missing value treatment is not needed. However, outlier treatment is necessary as it may affect the model

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# ### Here IQR method is used for outlier treatement

# %%
def whisker(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr = q3-q1
    lw = q1 - 1.5*iqr
    uw = q3 + 1.5*iqr
    return lw,uw

# %%
lw, uw = whisker(df1['Salary'])
print(f'Lower whisker: {lw}, Upper whisker:{uw}')
# Out:
# Lower whisker: -49577.5, Upper whisker:333746.5

# %%
for i in df1.select_dtypes(include = 'number').columns:
    lw,uw = whisker(df1[i])
    df1[i] = np.where(df1[i] < lw,lw,df1[i])
    df1[i] = np.where(df1[i] > uw,uw,df1[i])

# %%
# box plot to identify outliers
plt.figure(figsize = (8,5))
numeric_columns = df1.select_dtypes(include = 'number').columns
for i, col in enumerate(numeric_columns):
    plt.subplot(1,4,i+1)
    sns.boxplot(y = df1[col])
    plt.title(col)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# + ### All Outliers are removed

# %% [markdown]
# ## Check the skewness and kurtosis after outlier treatment

# %%
from scipy.stats import skew, kurtosis

#claculate skewness and kurtosis
skewness = df1[numeric_columns].apply(skew)
kurt = df1[numeric_columns].apply(lambda x: kurtosis(x, fisher=False))

print(skewness)
print(kurt)

#Identify positive and negative skewness (absolute value>1)
positive_skewness = skewness[skewness > 1]
negative_skewness = skewness[skewness < -1]

print('variable with positive skewness (skew > 1):\n', positive_skewness)
print('variable with negative skewness (skew < -1):\n', negative_skewness)

# Identify the platykurtic (kurtosis < 3) and leptokurtic (kurtosis > 3) distributions
platykurtic = kurt[kurt < 3]
leptokurtic = kurt[kurt > 3]

print('variables with platykurtic distribution (kurtosis < 3):\n', platykurtic)
print('variables with leptokurtic distribution (kurtosis > 3):\n', leptokurtic)
# Out:
# Salary    0.608371
# Year     -1.169779
# dtype: float64
# Salary    3.036315
# Year      3.496823
# dtype: float64
# variable with positive skewness (skew > 1):
#  Series([], dtype: float64)
# variable with negative skewness (skew < -1):
#  Year   -1.169779
# dtype: float64
# variables with platykurtic distribution (kurtosis < 3):
#  Series([], dtype: float64)
# variables with leptokurtic distribution (kurtosis > 3):
#  Salary    3.036315
# Year      3.496823
# dtype: float64

# %% [markdown]
# +  Data shows that 'Salary' and 'Year' exhibit higher-than-normal peaking and heavier tails, indicating they are more concentrated around their means and have more extreme values compared to a normal distribution.This preprocessing step has improved the quality of the data, leading to more reliable and robust predictive models.

# %% [markdown]
# # <span style='color:blue'>7. Visualization

# %%
# Histograms for numerical columns after outlier treatment
df1[numeric_columns].hist(bins= 5, figsize=(10,5), layout=(1,4))
plt.tight_layout()
plt.show()

# %% [markdown]
# + Insights

# %%
# pairplot - To visualize relationship between multiple pairs of variables
sns.pairplot(df1)

# %%
# Line plot for Salary by Year
plt.figure(figsize = (20, 5))
sns.lineplot(x='Year', y='Salary', data = df1)
plt.title('Salary Trends by Year')
plt.show()

# %%
# Histogram for Salary distribution
plt.figure(figsize = (20, 5))
sns.histplot(df1['Salary'], bins=30, kde=True)
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.show()

# %%
# Pair plot for numerical columns
sns.pairplot(df1[['Salary', 'Year', 'Company Size']], hue='Company Size')
plt.show()

# %%
# Box plot for Salary distribution by Employment Type
plt.figure(figsize=(20, 5))
sns.boxplot(x='Employment Type', y='Salary', data=df1)
plt.title('Salary Distribution by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Salary')
plt.show()

# %%
# Box plot for Salary distribution by Employment Type
plt.figure(figsize=(20, 5))
sns.violinplot(x='Company Size', y='Salary', data=df1)
plt.title('Salary Distibution by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Salary')
plt.show()

# %%
# KDE plot for Salary distribution by Expertise Level
plt.figure(figsize=(20, 5))
sns.kdeplot(data=df1, x='Salary', hue='Company Size', common_norm=False, fill=True, palette='Set1')
plt.title('KDE Plot of Salary by Expertise Level')
plt.xlabel('Salary')
plt.show()

# %%
# Assuming df1 is your DataFrame
top_n = 10  # Choose the top N job titles to display
avg_salary_by_job = df1.groupby('Job Title')['Salary'].mean().sort_values(ascending=False).head(top_n)

plt.bar(avg_salary_by_job.index, avg_salary_by_job)
plt.title(f'Top {top_n} Job Titles by Average Salary')
plt.ylabel('Average Salary')
plt.xlabel('Job Title')
plt.xticks(rotation=45, ha='right', fontsize=10)  # Adjust rotation, alignment, and font size as needed
plt.tight_layout()
plt.show()

# %%
# KDE plot for Salary distribution by Expertise Level
plt.figure(figsize=(20, 5))
sns.kdeplot(data=df1, x='Salary', hue='Expertise Level', common_norm=False, fill=True, palette='Set1')
plt.title('KDE Plot of Salary by Expertise Level')
plt.xlabel('Salary')
plt.show()

# %%
sns.violinplot(data=df1, x='Employment Type', y='Salary')
plt.title('Distribution of Data Scientist Salaries by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Salary')
plt.show()

# %%
# scatter plot to identify the relationship between dependent (Salary) and the independent variables
plt.figure(figsize=(5,5))
for i, col in enumerate(numeric_columns):
    plt.subplot(4,1, i+1)
    sns.scatterplot(data=df1,x=col,y='Salary')
    plt.xlabel(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df1[numeric_columns].corr(),annot=True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # <span style='color:blue'> 8. Feature Engineering

# %% [markdown]
# + ### Encode categorical features to numerical using techniques like one-hot encoding or label encoding to prepare thedata for machine learning algorithms. Use Label encoding for ordinal data and one-hot encoding for nominal data.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3300 entries, 0 to 3299
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job Title         3300 non-null   object
#  1   Employment Type   3300 non-null   object
#  2   Experience Level  3300 non-null   object
#  3   Expertise Level   3300 non-null   object
#  4   Salary            3300 non-null   float64
#  5   Company Location  3300 non-null   object
#  6   Company Size      3300 non-null   object
#  7   Year              3300 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 206.4+ KB

# %%
df1.shape
# Out:
# (3300, 8)

# %%
# One hot encode the categorical features (excluding the target variable)
categorical_features = df1.select_dtypes(include=['object']).columns
df1_encoded  = pd.get_dummies(df1, columns = categorical_features, drop_first = True)

df1.head()
# Out:
#         Job Title Employment Type Experience Level Expertise Level    Salary  \
# 0   Data Engineer       Full-Time           Senior          Expert  210000.0
# 1   Data Engineer       Full-Time           Senior          Expert  165000.0
# 2   Data Engineer       Full-Time           Senior          Expert  185900.0
# 3   Data Engineer       Full-Time           Senior          Expert  129300.0
# 4  Data Scientist       Full-Time           Senior          Expert  140000.0
#
#   Company Location Company Size    Year
# 0    United States       Medium  2023.0
# 1    United States       Medium  2023.0
# 2    United States       Medium  2023.0
# 3    United States       Medium  2023.0
# 4    United States       Medium  2023.0

# %%
# Assuming df1_encoded contains your encoded DataFrame with 'Salary' as the target variable
X = df1_encoded.drop('Salary', axis=1)  # Features excluding the target variable
y = df1_encoded['Salary']  # Target variable
df1.head()
# Out:
#         Job Title Employment Type Experience Level Expertise Level    Salary  \
# 0   Data Engineer       Full-Time           Senior          Expert  210000.0
# 1   Data Engineer       Full-Time           Senior          Expert  165000.0
# 2   Data Engineer       Full-Time           Senior          Expert  185900.0
# 3   Data Engineer       Full-Time           Senior          Expert  129300.0
# 4  Data Scientist       Full-Time           Senior          Expert  140000.0
#
#   Company Location Company Size    Year
# 0    United States       Medium  2023.0
# 1    United States       Medium  2023.0
# 2    United States       Medium  2023.0
# 3    United States       Medium  2023.0
# 4    United States       Medium  2023.0

# %%
X.shape
# Out:
# (3300, 192)

# %%
from sklearn.preprocessing import StandardScaler

# Scale the numerical features
Scaler = StandardScaler()
x_scaled = Scaler.fit_transform(X)

# Convert the result back to a DataFrame
x_scaled = pd.DataFrame(x_scaled, columns=X.columns)
x_scaled
# Out:
#           Year  Job Title_AI Developer  Job Title_AI Programmer  \
# 0     0.725074               -0.052295                -0.034837
# 1     0.725074               -0.052295                -0.034837
# 2     0.725074               -0.052295                -0.034837
# 3     0.725074               -0.052295                -0.034837
# 4     0.725074               -0.052295                -0.034837
# ...        ...                     ...                      ...
# 3295 -2.948160               -0.052295                -0.034837
# 3296 -2.213513               -0.052295                -0.034837
# 3297 -2.948160               -0.052295                -0.034837
# 3298 -2.948160               -0.052295                -0.034837
# 3299 -2.213513               -0.052295                -0.034837
#
#       Job Title_AI Scientist  Job Title_AWS Data Architect  \
# 0                  -0.074057                      -0.01741
# 1                  -0.074057                      -0.01741
# ...

# %% [markdown]
# # <span style='color:blue'>9. Data Splitting

# %%
# Splitting the dataset into 80-20 that is , 80% of the data is for training and 20% of the data is for testing

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # <span style='color:blue'>10. Model Selection

# %% [markdown]
# ### Models Selected: LinearRegression, DecisionTreeRegressor,ExtraTreeRegressor, RandomForestRegressor,GradientBoostingRegressor

# %% [markdown]
# #  <span style='color:blue'>11. Model Training & Evaluation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
model_name= []
RMSE = []
MSE = []
MAE = []
R2_score = []
models = [
 LinearRegression(),
 DecisionTreeRegressor(),
 ExtraTreeRegressor(),
 RandomForestRegressor(),
 GradientBoostingRegressor(), 
]
for model in models :
 model.fit(x_train , y_train)
 
 prediction = model.predict(x_test)
 
 model_name.append(model.__class__.__name__)
 
 RMSE.append(mean_squared_error(y_test, prediction, squared=False))
 MSE.append(mean_squared_error(y_test, prediction))
 MAE.append(mean_absolute_error(y_test, prediction))
 R2_score.append(r2_score(y_test, prediction) * 100)
models_df = pd.DataFrame({"Model-Name":model_name, "RMSE": RMSE, "MSE":MSE, "MAE":MAE, "R2_Score":R2_score})
models_df = models_df.set_index('Model-Name')
models_df.sort_values("R2_Score", ascending = False)
# Out:
#                                    RMSE           MSE           MAE  \
# Model-Name
# GradientBoostingRegressor  5.637233e+04  3.177840e+09  4.293064e+04
# RandomForestRegressor      5.652010e+04  3.194522e+09  4.192112e+04
# ExtraTreeRegressor         5.975459e+04  3.570611e+09  4.387971e+04
# DecisionTreeRegressor      5.982056e+04  3.578499e+09  4.414920e+04
# LinearRegression           1.452046e+18  2.108439e+36  1.209439e+17
#
#                                R2_Score
# Model-Name
# GradientBoostingRegressor  3.713105e+01
# RandomForestRegressor      3.680103e+01
# ExtraTreeRegressor         2.936065e+01
# DecisionTreeRegressor      2.920458e+01
# LinearRegression          -4.171240e+28

# %% [markdown]
# + ####  Certainly! Here's a concise summary of the insights from the models based on the provided metrics:
#
# + 1. GradientBoostingRegressor: Achieves the lowest RMSE and MAE among the models, indicating the most accurate salary predictions with a moderate R2 Score of 36.98%.
#
# + 2. RandomForestRegressor: Shows similar performance to GradientBoostingRegressor with slightly higher RMSE and MAE, and a slightly lower R2 Score of 36.14%.
#
# + 3. DecisionTreeRegressor: Performs less accurately than ensemble methods with higher RMSE, MAE, and lower R2 Score of 30.37%.
#
# + 4. ExtraTreeRegressor: Exhibits the highest RMSE, MAE, and lowest R2 Score of 25.55%, indicating less accurate predictions compared to other models.
#
# + 5. LinearRegression: Performs extremely poorly with wildly inaccurate metrics, suggesting severe issues in predicting salaries effectively.
#
# ### Best Model: Choose GradientBoostingRegressor for its superior accuracy in predicting salaries and reasonable explanation of variance in the data.

# %% [markdown]
# # <span style='color:blue'> 12. Feature Selection

# %% [markdown]
# ## 1. SelecKBbest

# %%
from sklearn.feature_selection import SelectKBest, f_regression
# SelectKBest with f_regression
selector_kbest = SelectKBest(score_func=f_regression, k=10)
X_kbest = selector_kbest.fit_transform(x_train, y_train)
# Get the selected feature indices
selected_indices_kbest = selector_kbest.get_support(indices=True)
# Get the names of the selected features
selected_features_kbest = x_train.columns[selected_indices_kbest]
print("Selected features using SelectKBest:", selected_features_kbest)
# Out:
# Selected features using SelectKBest: Index(['Year', 'Job Title_Data Analyst', 'Experience Level_Mid',
#        'Experience Level_Senior', 'Expertise Level_Expert',
#        'Expertise Level_Intermediate', 'Expertise Level_Junior',
#        'Company Location_India', 'Company Location_United Kingdom',
#        'Company Location_United States'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Assuming X_scaled contains all scaled features including selected ones
# Extracting only the selected features
selected_features = [
    'Year', 'Job Title_Data Analyst', 'Experience Level_Mid',
    'Experience Level_Senior', 'Expertise Level_Expert',
    'Expertise Level_Intermediate', 'Expertise Level_Junior',
    'Company Location_India', 'Company Location_United Kingdom',
    'Company Location_United States'
]

X_selected = x_scaled[selected_features]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Initialize models
models = [
    LinearRegression(),
    DecisionTreeRegressor(),
    ExtraTreeRegressor(),
    RandomForestRegressor(n_estimators=100, random_state=42),
    GradientBoostingRegressor(random_state=42)
]

# Train and evaluate each model
results = []
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)
    
    results.append({
        'Model': model.__class__.__name__,
        'RMSE': rmse,
        'R2 Score': r2
    })

# Display results in a DataFrame
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                        Model          RMSE  R2 Score
# 0           LinearRegression  59898.353597  0.290203
# 1      DecisionTreeRegressor  59972.516018  0.288445
# 2         ExtraTreeRegressor  59972.516018  0.288445
# 3      RandomForestRegressor  59983.238844  0.288190
# 4  GradientBoostingRegressor  59559.416895  0.298213

# %% [markdown]
# ### 2. SelectFromModel with Lasso (L1 Regularization)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
# Lasso model
lasso_model = Lasso(alpha=0.1) # Adjust alpha as needed
# SelectFromModel with Lasso
selector_lasso = SelectFromModel(lasso_model, max_features=10)
X_lasso = selector_lasso.fit_transform(X_train, y_train)
# Get the selected feature indices
selected_indices_lasso = selector_lasso.get_support(indices=True)
# Print selected feature names
selected_features_lasso = X_train.columns[selected_indices_lasso]
print("Selected features using SelectFromModel with Lasso:", selected_features_lasso)
# Out:
# Selected features using SelectFromModel with Lasso: Index(['Year', 'Job Title_Data Analyst', 'Experience Level_Mid',
#        'Experience Level_Senior', 'Expertise Level_Intermediate',
#        'Expertise Level_Junior', 'Company Location_India',
#        'Company Location_United Kingdom', 'Company Location_United States'],
#       dtype='object')

# %% [markdown]
# ### Train the models with selected features using L1 Regularization

# %%
X2 = x_scaled[['Year', 'Job Title_Data Analyst', 'Experience Level_Mid',
       'Experience Level_Senior', 'Expertise Level_Intermediate',
       'Expertise Level_Junior', 'Company Location_India',
       'Company Location_United Kingdom', 'Company Location_United States']]
X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y,test_size = 0.2,random_state = 42)
model_name= []
RMSE = []
MSE = []
MAE = []
R2_score = []
models = [
 LinearRegression(),
 DecisionTreeRegressor(),
 ExtraTreeRegressor(),
 RandomForestRegressor(),
 GradientBoostingRegressor(),

]
for model in models :
 model.fit(X2_train , y2_train)
 
 prediction = model.predict(X2_test)
 
 model_name.append(model.__class__.__name__)
 
 RMSE.append(mean_squared_error(y2_test, prediction, squared=False))
 MSE.append(mean_squared_error(y2_test, prediction))
 MAE.append(mean_absolute_error(y2_test, prediction))
 R2_score.append(r2_score(y2_test, prediction) * 100)
models_df = pd.DataFrame({"Model-Name":model_name, "RMSE": RMSE, "MSE":MSE, "MAE":MAE, "R2_Score":R2_score})
models_df = models_df.set_index('Model-Name')
models_df.sort_values("R2_Score", ascending = False)
# Out:
#                                    RMSE           MSE           MAE   R2_Score
# Model-Name
# GradientBoostingRegressor  59588.440460  3.550782e+09  44804.611737  29.752924
# LinearRegression           59888.843507  3.586674e+09  45310.355328  29.042866
# DecisionTreeRegressor      59972.516018  3.596703e+09  44798.457578  28.844455
# ExtraTreeRegressor         59972.516018  3.596703e+09  44798.457578  28.844455
# RandomForestRegressor      60027.232678  3.603269e+09  44921.244840  28.714557

# %% [markdown]
# ### 3. Recursive Feature Elimination (RFE) with Random Forest Regressor

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
# Random Forest regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
# RFE with Random Forest regressor
rfe_selector_regressor = RFE(estimator=rf_regressor, n_features_to_select=10, step=1)
X_rfe_regressor = rfe_selector_regressor.fit_transform(X_train, y_train)
# Get the selected feature indices
selected_indices_rfe_regressor = rfe_selector_regressor.get_support(indices=True)
# Get the names of the selected features
selected_features_rfe_regressor = X_train.columns[selected_indices_rfe_regressor]
print("Selected features using RFE with Random Forest Regressor:", selected_features_rfe_regressor)
# Out:
# Selected features using RFE with Random Forest Regressor: Index(['Year', 'Job Title_Data Analyst', 'Experience Level_Mid',
#        'Experience Level_Senior', 'Expertise Level_Expert',
#        'Expertise Level_Intermediate', 'Expertise Level_Junior',
#        'Company Location_India', 'Company Location_United Kingdom',
#        'Company Location_United States'],
#       dtype='object')

# %% [markdown]
# ### Train the models with selected features using Recursive Feature Elimination (RFE)

# %%
X3 = x_scaled[['Year', 'Job Title_Data Analyst', 'Experience Level_Mid',
       'Experience Level_Senior', 'Expertise Level_Expert',
       'Expertise Level_Intermediate', 'Expertise Level_Junior',
       'Company Location_India', 'Company Location_United Kingdom',
       'Company Location_United States']]
X3_train, X3_test, y3_train, y3_test = train_test_split(X3,y,test_size = 0.2,random_state = 42)
model_name= []
RMSE = []
MSE = []
MAE = []
R2_score = []
models = [
 LinearRegression(),
 DecisionTreeRegressor(),
 ExtraTreeRegressor(),
 RandomForestRegressor(),
 GradientBoostingRegressor(),
 
]
for model in models :
 model.fit(X3_train , y3_train)
 
 prediction = model.predict(X3_test)
 
 model_name.append(model.__class__.__name__)
 
 RMSE.append(mean_squared_error(y3_test, prediction, squared=False))
 MSE.append(mean_squared_error(y3_test, prediction))
 MAE.append(mean_absolute_error(y3_test, prediction))
 R2_score.append(r2_score(y3_test, prediction) * 100)
models_df = pd.DataFrame({"Model-Name":model_name, "RMSE": RMSE, "MSE":MSE, "MAE":MAE, "R2_Score":R2_score})
models_df = models_df.set_index('Model-Name')
models_df.sort_values("R2_Score", ascending = False)
# Out:
#                                    RMSE           MSE           MAE   R2_Score
# Model-Name
# GradientBoostingRegressor  59503.517946  3.540669e+09  44761.413227  29.953007
# LinearRegression           59898.353597  3.587813e+09  45331.743071  29.020329
# DecisionTreeRegressor      59972.516018  3.596703e+09  44798.457578  28.844455
# ExtraTreeRegressor         59972.516018  3.596703e+09  44798.457578  28.844455
# RandomForestRegressor      60012.974070  3.601557e+09  44877.333917  28.748418

# %% [markdown]
# ## 4. Feature selection using Variance Threshold

# %%
from sklearn.feature_selection import VarianceThreshold
# Variance Threshold
variance_selector = VarianceThreshold(threshold=0.1) # Adjust threshold as needed
X_variance = variance_selector.fit_transform(X_train)
# Get the selected feature indices
selected_indices_variance = [i for i, keep in enumerate(variance_selector.get_support()) if keep]
# Print selected feature names
selected_features_variance = X_train.iloc[:, selected_indices_variance].columns.tolist()
print("Selected features using Variance Threshold:", selected_features_variance)
# Out:
# Selected features using Variance Threshold: ['Year', 'Job Title_Data Analyst', 'Experience Level_Mid', 'Experience Level_Senior', 'Expertise Level_Expert', 'Expertise Level_Intermediate', 'Expertise Level_Junior', 'Company Location_India', 'Company Location_United Kingdom', 'Company Location_United States']

# %% [markdown]
# ### Train the models with selected features using Variance Threshold

# %%
X4 = x_scaled[['Year', 'Job Title_Data Analyst', 'Experience Level_Mid', 'Experience Level_Senior', 'Expertise Level_Expert', 
               'Expertise Level_Intermediate', 'Expertise Level_Junior', 'Company Location_India',
               'Company Location_United Kingdom', 'Company Location_United States']]
X4_train, X4_test, y4_train, y4_test = train_test_split(X4,y,test_size = 0.2,random_state = 42)
model_name= []
RMSE = []
MSE = []
MAE = []
R2_score = []
models = [
 LinearRegression(),
 DecisionTreeRegressor(),
 ExtraTreeRegressor(),
 RandomForestRegressor(),
 GradientBoostingRegressor()
 
]
for model in models :
 model.fit(X4_train , y4_train)
 
 prediction = model.predict(X4_test)
 
 model_name.append(model.__class__.__name__)
 
 RMSE.append(mean_squared_error(y4_test, prediction, squared=False))
 MSE.append(mean_squared_error(y4_test, prediction))
 MAE.append(mean_absolute_error(y4_test, prediction))
 R2_score.append(r2_score(y4_test, prediction) * 100)
models_df = pd.DataFrame({"Model-Name":model_name, "RMSE": RMSE, "MSE":MSE, "MAE":MAE, "R2_Score":R2_score})
models_df = models_df.set_index('Model-Name')
models_df.sort_values("R2_Score", ascending = False)
# Out:
#                                    RMSE           MSE           MAE   R2_Score
# Model-Name
# GradientBoostingRegressor  59608.804977  3.553210e+09  44813.649127  29.704902
# LinearRegression           59898.353597  3.587813e+09  45331.743071  29.020329
# DecisionTreeRegressor      59972.516018  3.596703e+09  44798.457578  28.844455
# ExtraTreeRegressor         59972.516018  3.596703e+09  44798.457578  28.844455
# RandomForestRegressor      59990.350454  3.598842e+09  44853.933172  28.802129

# %% [markdown]
# ### Finding the feature importance using GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
import pandas as pd

# Assuming X_selected contains selected features and y is the target variable

# Initialize GradientBoostingRegressor
gb_regressor = GradientBoostingRegressor(random_state=42)

# Fit the model
gb_regressor.fit(X_selected, y)

# Get feature importances
feature_importances = gb_regressor.feature_importances_

# Create a DataFrame to visualize feature importances
feature_importance_df = pd.DataFrame({
    'Feature': selected_features,
    'Importance': feature_importances
})

# Sort features by importance (descending order)
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.title('Feature Importance - GradientBoostingRegressor')
plt.gca().invert_yaxis()  # Invert y-axis to display most important feature on top
plt.show()

# Display feature importance DataFrame
print("Feature Importance:")
print(feature_importance_df)
# Out:
# Feature Importance:
#                            Feature  Importance
# 7           Company Location_India    0.285839
# 9   Company Location_United States    0.212698
# 1           Job Title_Data Analyst    0.140815
# 6           Expertise Level_Junior    0.097436
# 3          Experience Level_Senior    0.079965
# 4           Expertise Level_Expert    0.048893
# 2             Experience Level_Mid    0.046453
# 0                             Year    0.041794
# 5     Expertise Level_Intermediate    0.030477
# 8  Company Location_United Kingdom    0.015630

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Calculate the correlation matrix
corr = df1_encoded.corr()

# Find top 20 correlations with the target variable 'Salary'
top_corr_features = corr['Salary'].sort_values(ascending=False).head(25)  # Including 'Salary' itself

# Subset the correlation matrix to include only the top correlated features
top_corr_matrix = corr.loc[top_corr_features.index, top_corr_features.index]

# Plot the heatmap for the top correlated features
plt.figure(figsize=(12, 10))
sns.heatmap(top_corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Top 20 Correlations with Salary')
plt.show()

# Identify features with high correlation to the target variable
target_corr = corr['Salary'].sort_values(ascending = False)
print(target_corr)
# Out:
# Salary                             1.000000
# Company Location_United States     0.281491
# Experience Level_Senior            0.266798
# Expertise Level_Expert             0.266798
# Company Location_India             0.249178
#                                      ...
# Job Title_Data Analyst            -0.204437
# Company Location_United Kingdom   -0.205626
# Experience Level_Mid              -0.218302
# Expertise Level_Intermediate      -0.218302
# Expertise Level_Junior            -0.226225
# Name: Salary, Length: 193, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Salary'], kde=True)
plt.title('Distribution of Data Scientist Salaries')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # <span style='color:blue'> 14.Hyperparameter Tuning

# %% [markdown]
# # <span style='color:blue'>15. Result

# %% [markdown]
# # <span style='color:blue'>16. Model Deployment

# %% [markdown]
# ## Save the Model

# %% [markdown]
# ## Test with unseen data

# %% [markdown]
# # <span style='color:blue'>17. Limitations

# %% [markdown]
# # <span style='color:blue'>18. Conclusion

# %% [markdown]
# # <span style='color:blue'>19. Future Work

# %% [markdown]
# ### "I have also done visualizations in Power BI. For that, I saved the preprocessed data, imported it into Power BI, and used a sample of 1000 records to create the visualizations."
